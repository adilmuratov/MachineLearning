# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("FootballPlayerStats.csv", sep=";", encoding="ISO-8859-1")

players = data["Player"]
goals = data["Goals"]

plt.scatter(players.head(1000), ages.head(1000))
plt.show()
# Out:
# c:\Users\user\VSCodeProjects\MachineLearning\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 154 (\x9a) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
