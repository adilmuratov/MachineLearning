# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("2021-2022FootballPlayerStats.csv", sep=";", encoding="ISO-8859-1")

data.columns
# Out:
# Index(['Rk', 'Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Born', 'MP',
#        'Starts',
#        ...
#        'Off', 'Crs', 'TklW', 'PKwon', 'PKcon', 'OG', 'Recov', 'AerWon',
#        'AerLost', 'AerWon%'],
#       dtype='object', length=143)

# %%
players = data["Age"]
goals = data["Gls"]

plt.scatter(goals.head(3000), players.head(3000))
plt.show()

# %%
data["Pos"].unique()
# Out:
# array(['DF', 'MF', 'FW', 'MFFW', 'FWMF', 'GK', 'DFMF', 'FWDF', 'MFDF',
#        'DFFW', 'GKMF'], dtype=object)

# %%
for i in data["Pos"].unique():
    print(f"{i}:{data[(data["Pos"] == i) & (data["Goals"] > 0.01)]["Goals"].mean()}")
#GKMF - GK
#DFMF, DFFW, MFDF - LT
#MFFW, FWMF, FWDF - WG
# Out:
# DF:0.09746031746031747
# MF:0.15545454545454548
# FW:0.43612099644128116
# MFFW:0.2480952380952381
# FWMF:0.3383809523809524
# GK:nan
# DFMF:0.12625
# FWDF:0.32
# MFDF:0.12903225806451615
# DFFW:0.182
# GKMF:nan

# %%
data[(data["Pos"] == "FW")]["Goals"]
# Out:
# 4       0.00
# 5       0.00
# 6       0.00
# 7       0.50
# 13      0.31
#         ...
# 2887    0.09
# 2890    0.52
# 2898    0.44
# 2910    0.45
# 2919    0.21
# Name: Goals, Length: 419, dtype: float64

# %%
data.iloc[1531]
# Out:
# Rk                   1532
# Player     Javier Llabrés
# Nation                NaN
# Pos                  FWMF
# Squad            Mallorca
#                 ...
# OG                    0.0
# Recov                5.33
# AerWon               0.67
# AerLost               2.0
# AerWon%              25.0
# Name: 1531, Length: 143, dtype: object
